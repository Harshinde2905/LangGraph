# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict

# %%
# define state
class BMIState(TypedDict):
    weight_kg: float
    height_m : float
    bmi : float
    category : str

# %%
# creating node 1
def calculate_bmi(state:BMIState) -> BMIState:
    weight = state['weight_kg']
    height = state['height_m']
    
    bmi = weight/(height**2)
    
    state['bmi'] = round(bmi,2)
    
    return state

# creating node 2
def label_bmi(state:BMIState)->BMIState:
    bmi = state['bmi']
    if bmi<18.5:
        state['category'] = "Underweight"
    elif 18.5<= bmi <25:
        state['category'] = "Normal"
    elif 25 <= bmi <30:
        state['category'] = "Overweight"
    else:
        state['category'] = "Obese"
        
    return state

# %%
graph = StateGraph(BMIState)

#add nodes to the graph
graph.add_node('calculate_bmi', calculate_bmi)
graph.add_node('label_bmi', label_bmi)

#add edges to the graph
graph.add_edge(START,'calculate_bmi')
graph.add_edge('calculate_bmi', 'label_bmi')
graph.add_edge('label_bmi', END)

#compile the graph
workflow = graph.compile()

# %%
#execute the graph
initial_state = {'weight_kg':75, 'height_m':1.81}
final_state = workflow.invoke(initial_state)
print(final_state)
# Out:
# {'weight_kg': 75, 'height_m': 1.81, 'bmi': 22.89, 'category': 'Normal'}

# %%
from IPython.display import Image
import nest_asyncio
nest_asyncio.apply()
from langchain_core.runnables.graph import MermaidDrawMethod
# Image(workflow.get_graph().draw_mermaid_png(draw_method=MermaidDrawMethod.PYPPETEER))
png_data = workflow.get_graph().draw_mermaid_png(
    draw_method=MermaidDrawMethod.PLAYWRIGHT
)

display(Image(png_data))
# Out:
# [INFO] Starting Chromium download.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[9], line 6
#       4 from langchain_core.runnables.graph import MermaidDrawMethod
#       5 # Image(workflow.get_graph().draw_mermaid_png(draw_method=MermaidDrawMethod.PYPPETEER))
# ----> 6 png_data = workflow.get_graph().draw_mermaid_png(
#       7     draw_method=MermaidDrawMethod.PYPPETEER
#       8 )
#      10 display(Image(png_data))
#
# File c:\Users\hshinde3\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\runnables\graph.py:704, in Graph.draw_mermaid_png(self, curve_style, node_colors, wrap_label_n_words, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, frontmatter_config, base_url)
#     694 from langchain_core.runnables.graph_mermaid import (  # noqa: PLC0415
#     695     draw_mermaid_png,
#     696 )
#     698 mermaid_syntax = self.draw_mermaid(
#     699     curve_style=curve_style,
#     700     node_colors=node_colors,
#     701     wrap_label_n_words=wrap_label_n_words,
#     702     frontmatter_config=frontmatter_config,
#     703 )
# --> 704 return draw_mermaid_png(
#     705     mermaid_syntax=mermaid_syntax,
#     706     output_file_path=output_file_path,
#     707     draw_method=draw_method,
#     708     background_color=background_color,
#     709     padding=padding,
#     710     max_retries=max_retries,
#     711     retry_delay=retry_delay,
#     712     base_url=base_url,
#     713 )
#
# File c:\Users\hshinde3\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\runnables\graph_mermaid.py:316, in draw_mermaid_png(mermaid_syntax, output_file_path, draw_method, background_color, padding, max_retries, retry_delay, base_url)
#     291 """Draws a Mermaid graph as PNG using provided syntax.
#     292
#     293 Args:
#    (...)    313     ValueError: If an invalid draw method is provided.
#     314 """
#     315 if draw_method == MermaidDrawMethod.PYPPETEER:
# --> 316     img_bytes = asyncio.run(
#     317         _render_mermaid_using_pyppeteer(
#     318             mermaid_syntax, output_file_path, background_color, padding
#     319         )
#     320     )
#     321 elif draw_method == MermaidDrawMethod.API:
#     322     img_bytes = _render_mermaid_using_api(
#     323         mermaid_syntax,
#     324         output_file_path=output_file_path,
#    (...)    328         base_url=base_url,
#     329     )
#
# File c:\Users\hshinde3\AppData\Local\Programs\Python\Python312\Lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File c:\Users\hshinde3\AppData\Local\Programs\Python\Python312\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File c:\Users\hshinde3\AppData\Local\Programs\Python\Python312\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File c:\Users\hshinde3\AppData\Local\Programs\Python\Python312\Lib\asyncio\tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# File c:\Users\hshinde3\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\runnables\graph_mermaid.py:353, in _render_mermaid_using_pyppeteer(mermaid_syntax, output_file_path, background_color, padding, device_scale_factor)
#     350     msg = "Install Pyppeteer to use the Pyppeteer method: `pip install pyppeteer`."
#     351     raise ImportError(msg)
# --> 353 browser = await launch()
#     354 page = await browser.newPage()
#     356 # Setup Mermaid JS
#
# File c:\Users\hshinde3\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyppeteer\launcher.py:307, in launch(options, **kwargs)
#     239 async def launch(options: dict = None, **kwargs: Any) -> Browser:
#     240     """Start chrome process and return :class:`~pyppeteer.browser.Browser`.
#     241     This function is a shortcut to :meth:`Launcher(options, **kwargs).launch`.
#     242     Available options are:
#    (...)    305         option with extreme caution.
#     306     """
# --> 307     return await Launcher(options, **kwargs).launch()
#
# File c:\Users\hshinde3\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyppeteer\launcher.py:120, in Launcher.__init__(self, options, **kwargs)
#     118 if not self.chromeExecutable:
#     119     if not check_chromium():
# --> 120         download_chromium()
#     121     self.chromeExecutable = str(chromium_executable())
#     123 self.cmd = [self.chromeExecutable] + self.chromeArguments
#
# File c:\Users\hshinde3\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyppeteer\chromium_downloader.py:138, in download_chromium()
#     136 def download_chromium() -> None:
#     137     """Download and extract chromium."""
# --> 138     extract_zip(download_zip(get_url()), DOWNLOADS_FOLDER / REVISION)
#
# File c:\Users\hshinde3\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyppeteer\chromium_downloader.py:82, in download_zip(url)
#      80 r = http.request('GET', url, preload_content=False)
#      81 if r.status >= 400:
# ---> 82     raise OSError(f'Chromium downloadable not found at {url}: ' f'Received {r.data.decode()}.\n')
#      84 # 10 * 1024
#      85 _data = BytesIO()
#
# OSError: Chromium downloadable not found at https://storage.googleapis.com/chromium-browser-snapshots/Win_x64/1181205/chrome-win.zip: Received <?xml version='1.0' encoding='UTF-8'?><Error><Code>NoSuchKey</Code><Message>The specified key does not exist.</Message><Details>No such object: chromium-browser-snapshots/Win_x64/1181205/chrome-win.zip</Details></Error>.

# %%
# pip install pyppeteer
pyppeteer-install
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # pip install pyppeteer
# ----> 2 pyppeteer-install
#
# NameError: name 'pyppeteer' is not defined

# %%
pip install nest_asyncio
# Out:
# Requirement already satisfied: nest_asyncio in c:\users\hshinde3\appdata\local\programs\python\python312\lib\site-packages (1.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
