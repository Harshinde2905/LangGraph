# %%
from langgraph.graph import StateGraph
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
import os

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model='gemini-2.5-flash')

# %%
env_path = ('.env')
# print(os.getenv("GOOGLE_API_KEY"))

# %%
output = model.invoke("What is universe?")

# %%
print(output.content)
# Out:
# The **Universe** is, quite simply, **everything that exists**.
#
# This includes:
#
# 1.  **All of space and time:** The vast expanse in which everything is contained, and the dimension that orders events.
# 2.  **All matter:** From the smallest subatomic particles (quarks, electrons) to atoms, molecules, planets, stars, galaxies, and galaxy clusters. This also includes the mysterious **dark matter**, which we cannot directly observe but know exists due to its gravitational effects.
# 3.  **All energy:** Light, heat, kinetic energy, potential energy, and the equally mysterious **dark energy**, which is thought to be responsible for the accelerating expansion of the universe.
# 4.  **All physical laws and constants:** The fundamental rules that govern how everything interacts (like gravity, electromagnetism, the strong and weak nuclear forces).
#
# **Key Characteristics:**
#
# *   **Vastness:** It is incredibly immense, with distances measured in light-years (the distance light travels in one year). The *observable universe* alone has a diameter of about 93 billion light-years.
# *   **Age:** It is estimated to be about 13.8 billion years old, having originated from an event known as the Big Bang.
# *   **Expansion:** The universe is not static; it is constantly expanding, meaning the distances between galaxies are increasing over time. This expansion is accelerating, driven by dark energy.
# *   **Composition:** Only about 5% of the universe is made of "normal" baryonic matter (the stuff we can see and interact with). The rest is composed of roughly 27% dark matter and 68% dark energy.
# *   **Evolution:** From a hot, dense state after the Big Bang, the universe has cooled and expanded, allowing for the formation of fundamental particles, atoms, stars, and galaxies.
#
# In essence, the Universe is the grand totality of existence, encompassing everything we know, everything we can observe, and everything that remains a mystery. It is the ultimate subject of scientific inquiry and a source of profound wonder.
